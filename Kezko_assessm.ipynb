# %%
import pandas as pd

# Loads data from the CSV file './deliveries.csv' into a DataFrame named 'del_df'.
# The separator is specified as ';' since the data is not separated by commas by default.
del_df = pd.read_csv('./deliveries.csv', sep= ';')

# Displays the first 5 rows of the DataFrame to get a preview of the loaded data.
del_df.head()
# Out:
#                                          id  campaign_id  \
# 0          RPCtBwUAAYw2N2cGLMlm-0X9RlZ8ZQ==          NaN
# 1          RPCtBwUAAYw2JZ5ZnHbPWa9Mgfeamw==          NaN
# 2  dgTwrQcAAMfGCMbGCAGMNcXPsI8buTfq_C49eIw=         28.0
# 3  dgTwrQcAALjJCLfJCAGMNcXPpfPDnufKi-jyyz0=         28.0
# 4  dgTwrQcAAJnJCJjJCAGMNcXPpe2eqZyz7iMBYxs=         28.0
#
#           campaign_name  newsletter_id newsletter_name  template_id  \
# 0                   NaN            NaN             NaN          242
# 1                   NaN            NaN             NaN          244
# 2  Signup onboarding v3            NaN             NaN          223
# 3  Signup onboarding v3            NaN             NaN          205
# 4  Signup onboarding v3            NaN             NaN          222
#
#                 template_name  transactional_message_id  \
# 0                    Low data                       4.0
# 1              Video uploaded                       6.0
# 2  Share live stream features                       NaN
# 3  Share live stream features                       NaN
# 4           Onboarding Stream                       NaN
#
#   transactional_message_name                                          subject  \
# 0                   Low data                             Running out of data?
# 1             Video uploaded                     Video successfully uploaded!
# 2                        NaN  Take your streams to the next level with Dacast
# 3                        NaN  Take your streams to the next level with Dacast
# 4                        NaN                Start streaming with Dacast today
#
#    ...  unsubscribed_RFC3339  suppressed suppressed_RFC3339 failed  \
# 0  ...                   NaN         NaN                NaN    NaN
# 1  ...                   NaN         NaN                NaN    NaN
# 2  ...                   NaN         NaN                NaN    NaN
# 3  ...                   NaN         NaN                NaN    NaN
# 4  ...                   NaN         NaN                NaN    NaN
#
#    failed_RFC3339 drafted drafted_RFC3339  topic_unsubscribed  \
# 0             NaN     NaN             NaN                 NaN
# 1             NaN     NaN             NaN                 NaN
# 2             NaN     NaN             NaN                 NaN
# 3             NaN     NaN             NaN                 NaN
# 4             NaN     NaN             NaN                 NaN
#
#   topic_unsubscribed_RFC3339                         email
# 0                        NaN  reggidori@allin-partners.com
# 1                        NaN          hamdi@videoblogg.com
# 2                        NaN          maheshmahi@gamil.con
# 3                        NaN          anshul@realimapct.tv
# 4                        NaN       johncookj11@netzero.com
#
# [5 rows x 42 columns]

# %%
# Creates a new column named 'non existent', this column will contain True if the 'failure_message' column contains the text 'does not exist' or '5.1.1',
# which was found to indicate that the email could not be delivered because it is a non-existent email. Otherwise, it will contain False.
del_df['non existent'] = del_df['failure_message'].apply(lambda x: True if 'does not exist' in str(x) or '5.1.1' in str(x) else False)

# Displays the first 5 rows of the DataFrame with the new 'non existent' column.
del_df.head()
# Out:
#                                          id  campaign_id  \
# 0          RPCtBwUAAYw2N2cGLMlm-0X9RlZ8ZQ==          NaN
# 1          RPCtBwUAAYw2JZ5ZnHbPWa9Mgfeamw==          NaN
# 2  dgTwrQcAAMfGCMbGCAGMNcXPsI8buTfq_C49eIw=         28.0
# 3  dgTwrQcAALjJCLfJCAGMNcXPpfPDnufKi-jyyz0=         28.0
# 4  dgTwrQcAAJnJCJjJCAGMNcXPpe2eqZyz7iMBYxs=         28.0
#
#           campaign_name  newsletter_id newsletter_name  template_id  \
# 0                   NaN            NaN             NaN          242
# 1                   NaN            NaN             NaN          244
# 2  Signup onboarding v3            NaN             NaN          223
# 3  Signup onboarding v3            NaN             NaN          205
# 4  Signup onboarding v3            NaN             NaN          222
#
#                 template_name  transactional_message_id  \
# 0                    Low data                       4.0
# 1              Video uploaded                       6.0
# 2  Share live stream features                       NaN
# 3  Share live stream features                       NaN
# 4           Onboarding Stream                       NaN
#
#   transactional_message_name                                          subject  \
# 0                   Low data                             Running out of data?
# 1             Video uploaded                     Video successfully uploaded!
# 2                        NaN  Take your streams to the next level with Dacast
# 3                        NaN  Take your streams to the next level with Dacast
# 4                        NaN                Start streaming with Dacast today
#
#    ...  suppressed  suppressed_RFC3339 failed failed_RFC3339  drafted  \
# 0  ...         NaN                 NaN    NaN            NaN      NaN
# 1  ...         NaN                 NaN    NaN            NaN      NaN
# 2  ...         NaN                 NaN    NaN            NaN      NaN
# 3  ...         NaN                 NaN    NaN            NaN      NaN
# 4  ...         NaN                 NaN    NaN            NaN      NaN
#
#   drafted_RFC3339 topic_unsubscribed  topic_unsubscribed_RFC3339  \
# 0             NaN                NaN                         NaN
# 1             NaN                NaN                         NaN
# 2             NaN                NaN                         NaN
# 3             NaN                NaN                         NaN
# 4             NaN                NaN                         NaN
#
#                           email  non existent
# 0  reggidori@allin-partners.com         False
# 1          hamdi@videoblogg.com          True
# 2          maheshmahi@gamil.con         False
# 3          anshul@realimapct.tv         False
# 4       johncookj11@netzero.com         False
#
# [5 rows x 43 columns]

# %%
# Filters the DataFrame 'del_df' to select only the rows where the 'non existent' column is True, from those rows, it selects only the 'email' column
non_exist_df = del_df.loc[del_df['non existent'] == True, 'email']

# There are some emails that appear more than once, therefore, .drop_duplicates removes duplicate emails to get a list of unique emails.
non_exist_df.drop_duplicates(inplace=True)

# Resets the index of the 'non_exist_df' Series to be a simple numerical sequence.
non_exist_df.reset_index(drop=True, inplace=True)

# Displays the first 5 entries of the resulting Series with the unique non-existent emails.
non_exist_df.head()
# Out:
# 0            hamdi@videoblogg.com
# 1     wooodbenradel2018@gmail.com
# 2    keith456@stcharles.k12.la.us
# 3         chloeherman33@gmail.com
# 4      vatistasantinis1@gmail.com
# Name: email, dtype: object

# %%
# Saves the 'non_exist_df' Series (which contains the unique non-existent emails) to a CSV file named 'non_existent_emails.csv'.
# index=False prevents the Series index from being written to the CSV file.
non_exist_df.to_csv('./non_existent_emails.csv', index=False)
